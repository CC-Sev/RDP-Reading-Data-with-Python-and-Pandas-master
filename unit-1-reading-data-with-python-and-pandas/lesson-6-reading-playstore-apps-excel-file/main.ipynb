# %%
import numpy as np
import pandas as pd

data_url = 'https://github.com/ine-rmotr-projects/project-files/files/4086772/playstore.xlsx'

# %%
df = pd.read_excel('files/playstore.xlsx')
df
# Out:
#      Unnamed: 0                                                App  \
# 0             0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1             1                                Coloring book moana
# 2             2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3             3                              Sketch - Draw & Paint
# 4             4              Pixel Draw - Number Art Coloring Book
# ..          ...                                                ...
# 245         245                           Xero Accounting Software
# 246         246            MailChimp - Email, Marketing Automation
# 247         247               Crew - Free Messaging and Scheduling
# 248         248                      Asana: organize team projects
# 249         249                                   Google Analytics
#
#            Category  Rating     Installs  Type Price  Content_ID  \
# 0    ART_AND_DESIGN     4.1      10,000+  Free     0         101
# 1    ART_AND_DESIGN     3.9     500,000+  Free     0         101
# 2    ART_AND_DESIGN     4.7   5,000,000+  Free     0         101
# 3    ART_AND_DESIGN     4.5  50,000,000+  Free     0         102
# 4    ART_AND_DESIGN     4.3     100,000+  Free     0         101
# ..              ...     ...          ...   ...   ...         ...
# 245        BUSINESS     3.5     100,000+  Free     0         101
# 246        BUSINESS     4.1     500,000+  Free     0         101
# 247        BUSINESS     4.6     500,000+  Free     0         101
# 248        BUSINESS     4.3   1,000,000+  Free     0         101
# 249        BUSINESS     4.5   1,000,000+  Free     0         101
#
#                         Genres       Last_Updated
# 0                 Art & Design    January 7, 2018
# 1    Art & Design;Pretend Play   January 15, 2018
# 2                 Art & Design     August 1, 2018
# 3                 Art & Design       June 8, 2018
# 4      Art & Design;Creativity      June 20, 2018
# ..                         ...                ...
# 245                   Business      July 30, 2018
# 246                   Business      July 25, 2018
# 247                   Business      July 20, 2018
# 248                   Business      July 26, 2018
# 249                   Business  February 13, 2018
#
# [250 rows x 10 columns]

# %%
pd.ExcelFile('files/playstore.xlsx').sheet_names
# Out:
# ['Google_playstore', 'Content_ID']

# %% [markdown]
# **Test for date_time**

# %%
def test_last_updated_datetime():
    assert playstore_df['Last_Updated'].dtype == np.dtype('<datetime64[ns]')

# %%
df['Last_Updated']
# Out:
# 0        January 7, 2018
# 1       January 15, 2018
# 2         August 1, 2018
# 3           June 8, 2018
# 4          June 20, 2018
#              ...
# 245        July 30, 2018
# 246        July 25, 2018
# 247        July 20, 2018
# 248        July 26, 2018
# 249    February 13, 2018
# Name: Last_Updated, Length: 250, dtype: object

# %%
parsed_Last_Updated = pd.read_excel('files/playstore.xlsx',
        usecols = ['Last_Updated'],
        parse_dates=['Last_Updated'])

# %% [markdown]
# **Test for top 25 index**

# %%
def test_top25_index():
    assert playstore_df.iloc[23]['App'] == 'Ulta Beauty'
    assert playstore_df.iloc[1]['App'] == 'CDL Practice Test 2018 Edition'

# %%
df['App'].head(25)
# Out:
# 0        Photo Editor & Candy Camera & Grid & ScrapBook
# 1                                   Coloring book moana
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3                                 Sketch - Draw & Paint
# 4                 Pixel Draw - Number Art Coloring Book
# 5                            Paper flowers instructions
# 6               Smoke Effect Photo Maker - Smoke Editor
# 7                                      Infinite Painter
# 8                                  Garden Coloring Book
# 9                         Kids Paint Free - Drawing Fun
# 10                              Text on Photo - Fonteee
# 11              Name Art Photo Editor - Focus n Filters
# 12                       Tattoo Name On My Photo Editor
# 13                                Mandala Coloring Book
# 14      3D Color Pixel by Number - Sandbox Art Coloring
# 15                      Learn To Draw Kawaii Characters
# 16         Photo Designer - Write your name with shapes
# 17                             350 Diy Room Decor Ideas
# 18                        FlipaClip - Cartoon animation
# 19                                         ibis Paint X
# 20                          Logo Maker - Small Business
# 21            Boys Photo Editor - Six Pack & Men's Suit
# 22              Superheroes Wallpapers | 4K Backgrounds
# 23                               Mcqueen Coloring pages
# 24                          HD Mickey Minnie Wallpapers
# Name: App, dtype: object

# %%
df.loc[df['App'] == 'Ulta Beauty']
# Out:
#      Unnamed: 0          App Category  Rating    Installs  Type Price  \
# 107         107  Ulta Beauty   BEAUTY     4.7  1,000,000+  Free     0
#
#      Content_ID  Genres  Last_Updated
# 107         101  Beauty  June 5, 2018

# %%
df.loc[df['App'] == 'CDL Practice Test 2018 Edition']
# Out:
#     Unnamed: 0                             App           Category  Rating  \
# 61          61  CDL Practice Test 2018 Edition  AUTO_AND_VEHICLES     4.9
#
#     Installs  Type Price  Content_ID           Genres  Last_Updated
# 61  100,000+  Free     0         101  Auto & Vehicles  July 3, 2018

# %%
top_25_index = df[['App', 'Rating']].sort_values(by='Rating', ascending=False).head(25)

# %%
top_25_index
# Out:
#                                                    App  Rating
# 79                             Tickets + PDA 2018 Exam     4.9
# 64               DMV Permit Practice Test 2018 Edition     4.9
# 177           eBoox new: Reader for fb2 epub zip books     4.9
# 55   Tickets SDA 2018 and Exam from the State Traff...     4.9
# 61                      CDL Practice Test 2018 Edition     4.9
# 99                      ipsy: Makeup, Beauty, and Tips     4.9
# 151         Free Books - Spirit Fanfiction and Stories     4.8
# 161                        ReadEra – free ebook reader     4.8
# 70   Fines of the State Traffic Safety Inspectorate...     4.8
# 196                         Job Search by ZipRecruiter     4.8
# 235                     Tiny Scanner Pro: PDF Doc Scan     4.8
# 25                          Harley Quinn wallpapers HD     4.8
# 74                          Tickets SDA 2019 + Exam RF     4.8
# 73                                              PDD-UA     4.8
# 108                               Prom MakeUp Tutorial     4.8
# 156             Offline: English to Tagalog Dictionary     4.7
# 22             Superheroes Wallpapers | 4K Backgrounds     4.7
# 107                                        Ulta Beauty     4.7
# 106                              Tie - Always be happy     4.7
# 100                    Natural recipes for your beauty     4.7
# 98                          Hush - Beauty for Everyone     4.7
# 162                          NOOK App for NOOK Devices     4.7
# 234      TurboScan: scan documents and receipts in PDF     4.7
# 137                         Methods of teeth whitening     4.7
# 26                       Colorfit - Drawing & Coloring     4.7

# %% [markdown]
# **Test for top 25 shape**

# %%
def test_top25_shape():
    assert playstore_df.shape == (25, 5)

# %%
df.shape
# Out:
# (250, 10)

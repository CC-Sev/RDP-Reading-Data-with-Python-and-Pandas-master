# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_json('files/artists.json')
df
# Out:
#                  name        years                         genre nationality  \
# 0   Amedeo Modigliani  1884 - 1920                 Expressionism     Italian
# 1  Vasiliy Kandinskiy  1866 - 1944  Expressionism,Abstractionism     Russian
# 2        Diego Rivera  1886 - 1957       Social Realism,Muralism     Mexican
# 3        Claude Monet  1840 - 1926                 Impressionism      French
# 4       Rene Magritte  1898 - 1967      Surrealism,Impressionism     Belgian
#
#                                                  bio
# 0  [{'full name': 'Amedeo Clemente Modigliani', '...
# 1  [{'full name': 'Wassily Wassilyevich Kandinsky...
# 2  [{'full name': 'Diego María de la Concepción J...
# 3  [{'full name': 'Oscar-Claude Monet', 'pronunci...
# 4  [{'full name': 'René François Ghislain Magritt...

# %%
from pandas import json_normalize
import json

# %%
with open('files/artists.json') as file:
    json_dict = json.load(file)

# %%
json_dict
# Out:
# [{'name': 'Amedeo Modigliani',
#   'years': '1884 - 1920',
#   'genre': 'Expressionism',
#   'nationality': 'Italian',
#   'bio': [{'full name': 'Amedeo Clemente Modigliani',
#     'pronunciation': '[ameˈdɛːo modiʎˈʎaːni]',
#     'life span': '12 July 1884 – 24 January 1920',
#     'info': "was an Italian Jewish painter and sculptor who worked mainly in France. He is known for portraits and nudes in a modern style characterized by elongation of faces, necks, and figures that were not received well during his lifetime but later found acceptance. Modigliani spent his youth in Italy, where he studied the art of antiquity and the Renaissance. In 1906 he moved to Paris, where he came into contact with such artists as Pablo Picasso and Constantin Brâncuși. By 1912 Modigliani was exhibiting highly stylized sculptures with Cubists of the Section d'Or group at the Salon d'Automne.",
#     'wikipedia': 'http://en.wikipedia.org/wiki/Amedeo_Modigliani',
#     'paintings': 193}]},
# ...

# %%
json_dict.key()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 json_dict.key()
#
# AttributeError: 'list' object has no attribute 'key'

# %%
json_dict.values()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 json_dict.values()
#
# AttributeError: 'list' object has no attribute 'values'

# %%
df = json_normalize(json_dict)
df
# Out:
#                  name        years                         genre nationality  \
# 0   Amedeo Modigliani  1884 - 1920                 Expressionism     Italian
# 1  Vasiliy Kandinskiy  1866 - 1944  Expressionism,Abstractionism     Russian
# 2        Diego Rivera  1886 - 1957       Social Realism,Muralism     Mexican
# 3        Claude Monet  1840 - 1926                 Impressionism      French
# 4       Rene Magritte  1898 - 1967      Surrealism,Impressionism     Belgian
#
#                                                  bio
# 0  [{'full name': 'Amedeo Clemente Modigliani', '...
# 1  [{'full name': 'Wassily Wassilyevich Kandinsky...
# 2  [{'full name': 'Diego María de la Concepción J...
# 3  [{'full name': 'Oscar-Claude Monet', 'pronunci...
# 4  [{'full name': 'René François Ghislain Magritt...

# %%
df_norm = json_normalize(json_dict,
                    record_path='bio',
                    meta=['name', 'years']
                    )
df_norm
# Out:
#                                            full name  \
# 0                         Amedeo Clemente Modigliani
# 1                     Wassily Wassilyevich Kandinsky
# 2  Diego María de la Concepción Juan Nepomuceno E...
# 3                                 Oscar-Claude Monet
# 4                    René François Ghislain Magritte
#
#                                        pronunciation  \
# 0                             [ameˈdɛːo modiʎˈʎaːni]
# 1  Васи́лий Васи́льевич Канди́нский, tr. Vasíliy ...
# 2                                   [ˈdjeɣo riˈβeɾa]
# 3                                        [klod mɔnɛ]
# 4                        [ʁəne fʁɑ̃swa ɡilɛ̃ maɡʁit]
#
#                                            life span  \
# 0                     12 July 1884 – 24 January 1920
# 1  16 December [O.S. 4 December] 1866 – 13 Decemb...
# 2               December 8, 1886 – November 24, 1957
# 3                 14 November 1840 – 5 December 1926
# ...

# %%
df_norm.set_index('name')
# Out:
#                                                             full name  \
# name
# Amedeo Modigliani                          Amedeo Clemente Modigliani
# Vasiliy Kandinskiy                     Wassily Wassilyevich Kandinsky
# Diego Rivera        Diego María de la Concepción Juan Nepomuceno E...
# Claude Monet                                       Oscar-Claude Monet
# Rene Magritte                         René François Ghislain Magritte
#
#                                                         pronunciation  \
# name
# Amedeo Modigliani                              [ameˈdɛːo modiʎˈʎaːni]
# Vasiliy Kandinskiy  Васи́лий Васи́льевич Канди́нский, tr. Vasíliy ...
# Diego Rivera                                         [ˈdjeɣo riˈβeɾa]
# Claude Monet                                              [klod mɔnɛ]
# Rene Magritte                             [ʁəne fʁɑ̃swa ɡilɛ̃ maɡʁit]
#
#                                                             life span  \
# name
# ...

# %%
def test_artists():
    assert artists.iloc[3]['genre'] == 'Impressionism'

# %%
df.iloc[3]['genre']
# Out:
# 'Impressionism'

# %%
def test_index():
    i = pd.Index(['Amedeo Modigliani', 'Vasiliy Kandinskiy', 'Diego Rivera',
              'Claude Monet', 'Rene Magritte'])

    assert artists.index.equals(i)

# %%
i = pd.Index(['Amedeo Modigliani', 'Vasiliy Kandinskiy', 'Diego Rivera',
              'Claude Monet', 'Rene Magritte'])
df.index.equals(i)
# Out:
# False

# %%
df.loc[df['name'] == i]
# Out:
#                  name        years                         genre nationality  \
# 0   Amedeo Modigliani  1884 - 1920                 Expressionism     Italian
# 1  Vasiliy Kandinskiy  1866 - 1944  Expressionism,Abstractionism     Russian
# 2        Diego Rivera  1886 - 1957       Social Realism,Muralism     Mexican
# 3        Claude Monet  1840 - 1926                 Impressionism      French
# 4       Rene Magritte  1898 - 1967      Surrealism,Impressionism     Belgian
#
#                                                  bio
# 0  [{'full name': 'Amedeo Clemente Modigliani', '...
# 1  [{'full name': 'Wassily Wassilyevich Kandinsky...
# 2  [{'full name': 'Diego María de la Concepción J...
# 3  [{'full name': 'Oscar-Claude Monet', 'pronunci...
# 4  [{'full name': 'René François Ghislain Magritt...

# %%
def test_shape():
    assert artists.shape == (5, 3)

# %%
df2 = pd.read_json('files/artists.json')
df2 = df2.set_index('name')
df2
# Out:
#                           years                         genre nationality  \
# name
# Amedeo Modigliani   1884 - 1920                 Expressionism     Italian
# Vasiliy Kandinskiy  1866 - 1944  Expressionism,Abstractionism     Russian
# Diego Rivera        1886 - 1957       Social Realism,Muralism     Mexican
# Claude Monet        1840 - 1926                 Impressionism      French
# Rene Magritte       1898 - 1967      Surrealism,Impressionism     Belgian
#
#                                                                   bio
# name
# Amedeo Modigliani   [{'full name': 'Amedeo Clemente Modigliani', '...
# Vasiliy Kandinskiy  [{'full name': 'Wassily Wassilyevich Kandinsky...
# Diego Rivera        [{'full name': 'Diego María de la Concepción J...
# Claude Monet        [{'full name': 'Oscar-Claude Monet', 'pronunci...
# Rene Magritte       [{'full name': 'René François Ghislain Magritt...

# %%
df2 = df2.drop('bio', axis=1)

# %%
df2.shape
# Out:
# (5, 3)

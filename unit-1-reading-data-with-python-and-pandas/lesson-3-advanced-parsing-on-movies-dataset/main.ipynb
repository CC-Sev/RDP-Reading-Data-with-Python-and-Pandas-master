# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
column_names = ['color', 'director_name', 'num_critic_for_reviews', 'duration',
                'gross', 'movie_title', 'num_user_for_reviews',	'country',
                'cotent_rating', 'budget', 'title_year', 'imdb_score', 'genre']

# %%
df = pd.read_csv('files/movies.csv',
                 sep = '|',
                 header=None,
                 names = column_names,
                 na_values='?',
                 thousands= ',')
df
# Out:
#     color      director_name  num_critic_for_reviews  duration        gross  \
# 0   Color      James Cameron                   723.0     178.0  760505847.0
# 1   Color     Gore Verbinski                   302.0     169.0  309404152.0
# 2   Color         Sam Mendes                   602.0     148.0  200074175.0
# 3   Color  Christopher Nolan                   813.0     164.0  448130642.0
# 4     NaN        Doug Walker                     NaN       NaN          NaN
# ..    ...                ...                     ...       ...          ...
# 95  Color         James Gunn                   653.0     121.0  333130696.0
# 96  Color  Christopher Nolan                   712.0     169.0  187991439.0
# 97  Color  Christopher Nolan                   642.0     148.0  292568851.0
# 98  Color       Hideaki Anno                     1.0     120.0          NaN
# 99  Color      Peter Jackson                   645.0     182.0  303001229.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   color                   99 non-null     object
#  1   director_name           100 non-null    object
#  2   num_critic_for_reviews  99 non-null     float64
#  3   duration                99 non-null     float64
#  4   gross                   97 non-null     float64
#  5   movie_title             100 non-null    object
#  6   num_user_for_reviews    99 non-null     float64
#  7   country                 99 non-null     object
#  8   cotent_rating           98 non-null     object
#  9   budget                  96 non-null     float64
#  10  title_year              99 non-null     float64
#  11  imdb_score              100 non-null    float64
#  12  genre                   100 non-null    object
# dtypes: float64(7), object(6)
# memory usage: 10.3+ KB

# %%
df.duplicated().any()
# Out:
# False

# %%
df.isna().any()
# Out:
# color                      True
# director_name             False
# num_critic_for_reviews     True
# duration                   True
# gross                      True
# movie_title               False
# num_user_for_reviews       True
# country                    True
# cotent_rating              True
# budget                     True
# title_year                 True
# imdb_score                False
# genre                     False
# dtype: bool

# %%
df.isna().sum()
# Out:
# color                     1
# director_name             0
# num_critic_for_reviews    1
# duration                  1
# gross                     3
# movie_title               0
# num_user_for_reviews      1
# country                   1
# cotent_rating             2
# budget                    4
# title_year                1
# imdb_score                0
# genre                     0
# dtype: int64

# %%
df = df.dropna()

# %%
df
# Out:
#     color      director_name  num_critic_for_reviews  duration        gross  \
# 0   Color      James Cameron                   723.0     178.0  760505847.0
# 1   Color     Gore Verbinski                   302.0     169.0  309404152.0
# 2   Color         Sam Mendes                   602.0     148.0  200074175.0
# 3   Color  Christopher Nolan                   813.0     164.0  448130642.0
# 5   Color     Andrew Stanton                   462.0     132.0   73058679.0
# ..    ...                ...                     ...       ...          ...
# 94  Color    Jonathan Mostow                   280.0     109.0  150350192.0
# 95  Color         James Gunn                   653.0     121.0  333130696.0
# 96  Color  Christopher Nolan                   712.0     169.0  187991439.0
# 97  Color  Christopher Nolan                   642.0     148.0  292568851.0
# 99  Color      Peter Jackson                   645.0     182.0  303001229.0
#
# ...

# %% [markdown]
# **1.Test for movies with a budget of at least $105,000,000**

# %%
def test_budget():
    assert movies.loc[:, 'budget'].min() == 105_000_000.0

# %%
df.loc[:, 'budget'].min() == 105_000_000.0
# Out:
# [True]

# %%
df.loc[df['budget'] <= 105_000_000.0]
# Out:
#     color director_name  num_critic_for_reviews  duration        gross  \
# 50  Color  Baz Luhrmann                   490.0     143.0  144812796.0
#
#           movie_title  num_user_for_reviews    country cotent_rating  \
# 50  The Great Gatsby                  753.0  Australia         PG-13
#
#          budget  title_year  imdb_score  genre
# 50  105000000.0      2013.0         7.3  Drama

# %% [markdown]
# **Tested the that there is at least one movie with a minimum budget of $105,000,000.00.**

# %% [markdown]
# **2. Now test for unique countries where movies originated from**

# %%
df['country'].unique()
# Out:
# array(['USA', 'UK', 'New Zealand', 'Canada', 'Australia'], dtype=object)

# %%
df['country'].value_counts()
# Out:
# country
# USA            87
# UK              5
# New Zealand     2
# Canada          1
# Australia       1
# Name: count, dtype: int64

# %% [markdown]
# **3. Test shape of data frame**

# %%
df.shape
# Out:
# (96, 13)

# %%
import numpy as np
import pandas as pd

data_url = 'https://github.com/ine-rmotr-projects/project-files/files/4086772/playstore.xlsx'

# %%
df = pd.read_excel('files/playstore.xlsx',
                   header=0,
                   usecols=[1,2,3,4,7,8,9],
                   parse_dates=['Last_Updated'])
df
# Out:
#                                                    App        Category  \
# 0       Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 1                                  Coloring book moana  ART_AND_DESIGN
# 2    U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 3                                Sketch - Draw & Paint  ART_AND_DESIGN
# 4                Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN
# ..                                                 ...             ...
# 245                           Xero Accounting Software        BUSINESS
# 246            MailChimp - Email, Marketing Automation        BUSINESS
# 247               Crew - Free Messaging and Scheduling        BUSINESS
# 248                      Asana: organize team projects        BUSINESS
# 249                                   Google Analytics        BUSINESS
#
#      Rating     Installs  Content_ID                     Genres Last_Updated
# ...

# %% [markdown]
# **Test for content id and its shape**

# %%
def test_content_id_1():
    assert content_id_df.shape == (250,1)

# %%
df['Content_ID'].unique()
# Out:
# array([101, 102, 103, 104])

# %%
df['Content_ID'].shape
# Out:
# (250,)

# %% [markdown]
# **Test for content and rating**

# %%
def test_content_id_2():
    content_id_head = pd.DataFrame({'Content_Rating': ['Everyone', 'Everyone', 'Everyone', 'Teen', 'Everyone']},
                                   index=[101, 101, 101, 102, 101])
                                
    assert content_id_df.head().equals(content_id_head)

# %%
content_rating = df.set_index('Content_ID')

# %%
content_rating.head()
# Out:
#                                                           App        Category  \
# Content_ID
# 101            Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 101                                       Coloring book moana  ART_AND_DESIGN
# 101         U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 102                                     Sketch - Draw & Paint  ART_AND_DESIGN
# 101                     Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN
#
#             Rating     Installs                     Genres Last_Updated
# Content_ID
# 101            4.1      10,000+               Art & Design   2018-01-07
# 101            3.9     500,000+  Art & Design;Pretend Play   2018-01-15
# 101            4.7   5,000,000+               Art & Design   2018-08-01
# 102            4.5  50,000,000+               Art & Design   2018-06-08
# 101            4.3     100,000+    Art & Design;Creativity   2018-06-20

# %%
content_rating = content_rating.sort_values(by='Rating', ascending=False)
content_rating.head()
# Out:
#                                                           App  \
# Content_ID
# 101                  eBoox new: Reader for fb2 epub zip books
# 101         Tickets SDA 2018 and Exam from the State Traff...
# 101                            CDL Practice Test 2018 Edition
# 101                            ipsy: Makeup, Beauty, and Tips
# 101                                   Tickets + PDA 2018 Exam
#
#                        Category  Rating    Installs             Genres  \
# Content_ID
# 101         BOOKS_AND_REFERENCE     4.9     50,000+  Books & Reference
# 101           AUTO_AND_VEHICLES     4.9    100,000+    Auto & Vehicles
# 101           AUTO_AND_VEHICLES     4.9    100,000+    Auto & Vehicles
# 101                      BEAUTY     4.9  1,000,000+             Beauty
# 101           AUTO_AND_VEHICLES     4.9  1,000,000+    Auto & Vehicles
#
#            Last_Updated
# Content_ID
# 101          2018-07-17
# 101          2018-07-18
# 101          2018-07-03
# ...

# %% [markdown]
# **Test for playstore shape**

# %%
def test_playstore_1():
    assert playstore_df.shape == (250,9)

# %%
df2 = pd.read_excel('files/playstore.xlsx',
                    parse_dates=['Last_Updated'])
df2.head(5)
# Out:
#    Unnamed: 0                                                App  \
# 0           0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1           1                                Coloring book moana
# 2           2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3           3                              Sketch - Draw & Paint
# 4           4              Pixel Draw - Number Art Coloring Book
#
#          Category  Rating     Installs  Type Price  Content_ID  \
# 0  ART_AND_DESIGN     4.1      10,000+  Free     0         101
# 1  ART_AND_DESIGN     3.9     500,000+  Free     0         101
# 2  ART_AND_DESIGN     4.7   5,000,000+  Free     0         101
# 3  ART_AND_DESIGN     4.5  50,000,000+  Free     0         102
# 4  ART_AND_DESIGN     4.3     100,000+  Free     0         101
#
#                       Genres Last_Updated
# 0               Art & Design   2018-01-07
# 1  Art & Design;Pretend Play   2018-01-15
# 2               Art & Design   2018-08-01
# ...

# %%
df2 = df2.drop(df2.columns[0], axis=1)

# %%
df2.shape
# Out:
# (250, 9)

# %%
def test_playstore_2():
    assert playstore_df.iloc[3]['App'] == 'Sketch - Draw & Paint'

# %%
df2.iloc[3]['App']
# Out:
# 'Sketch - Draw & Paint'

# %%
df2.head(5)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#       Installs  Type Price  Content_ID                     Genres Last_Updated
# 0      10,000+  Free     0         101               Art & Design   2018-01-07
# 1     500,000+  Free     0         101  Art & Design;Pretend Play   2018-01-15
# 2   5,000,000+  Free     0         101               Art & Design   2018-08-01
# 3  50,000,000+  Free     0         102               Art & Design   2018-06-08
# 4     100,000+  Free     0         101    Art & Design;Creativity   2018-06-20

# %%
df3 = pd.ExcelFile('files/playstore.xlsx')

# %%
df3.sheet_names
# Out:
# ['Google_playstore', 'Content_ID']

# %%
ps_df = df3.parse(index_col=0).head(3)

# %%
ps_df
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
#
#      Installs  Type Price  Content_ID                     Genres  \
# 0     10,000+  Free     0         101               Art & Design
# 1    500,000+  Free     0         101  Art & Design;Pretend Play
# 2  5,000,000+  Free     0         101               Art & Design
#
#        Last_Updated
# 0   January 7, 2018
# 1  January 15, 2018
# 2    August 1, 2018

# %%
cont_rate = df3.parse('Content_ID',
                        index_col='Content_ID')

# %%
cont_rate.head()
# Out:
#            Content_Rating
# Content_ID
# 101              Everyone
# 101              Everyone
# 101              Everyone
# 102                  Teen
# 101              Everyone

# %%
google_df = pd.read_excel('files/playstore.xlsx',
                          sheet_name='Google_playstore')

# %%
google_df.head()
# Out:
#    Unnamed: 0                                                App  \
# 0           0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1           1                                Coloring book moana
# 2           2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3           3                              Sketch - Draw & Paint
# 4           4              Pixel Draw - Number Art Coloring Book
#
#          Category  Rating     Installs  Type Price  Content_ID  \
# 0  ART_AND_DESIGN     4.1      10,000+  Free     0         101
# 1  ART_AND_DESIGN     3.9     500,000+  Free     0         101
# 2  ART_AND_DESIGN     4.7   5,000,000+  Free     0         101
# 3  ART_AND_DESIGN     4.5  50,000,000+  Free     0         102
# 4  ART_AND_DESIGN     4.3     100,000+  Free     0         101
#
#                       Genres      Last_Updated
# 0               Art & Design   January 7, 2018
# 1  Art & Design;Pretend Play  January 15, 2018
# 2               Art & Design    August 1, 2018
# ...

# %%
cont_df = pd.read_excel('files/playstore.xlsx',
                        sheet_name='Content_ID')
cont_df.head()
# Out:
#    Content_ID Content_Rating
# 0         101       Everyone
# 1         101       Everyone
# 2         101       Everyone
# 3         102           Teen
# 4         101       Everyone

# %%
with pd.ExcelWriter('out.xlsx') as writer:
    cont_rate.to_excel(writer)

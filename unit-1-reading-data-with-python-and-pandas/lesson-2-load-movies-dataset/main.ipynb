# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as pl

# %%
df = pd.read_csv('files/movies.csv',
                 header = None,
                 sep = '|',
                 na_values = ['', '?'])
df.head()
# Out:
#       0                  1      2      3            4   \
# 0  Color      James Cameron  723.0  178.0  760505847.0
# 1  Color     Gore Verbinski  302.0  169.0  309404152.0
# 2  Color         Sam Mendes  602.0  148.0  200074175.0
# 3  Color  Christopher Nolan  813.0  164.0  448130642.0
# 4    NaN        Doug Walker    NaN    NaN          NaN
#
#                                                   5       6    7      8   \
# 0                                            Avatar   3054.0  USA  PG-13
# 1          Pirates of the Caribbean: At World's End   1238.0  USA  PG-13
# 2                                           Spectre    994.0   UK  PG-13
# 3                             The Dark Knight Rises   2701.0  USA  PG-13
# 4  Star Wars: Episode VII - The Force Awakens    ...     NaN  NaN    NaN
#
#               9       10   11           12
# 0  237,000,000.0  2009.0  7.9       Action
# 1  300,000,000.0  2007.0  7.1       Action
# 2  245,000,000.0  2015.0  6.8       Action
# 3  250,000,000.0  2012.0  8.5       Action
# 4            NaN     NaN  7.1  Documentary

# %%
df.shape
# Out:
# (100, 13)

# %%
df.isna().sum()
# Out:
# 0     1
# 1     0
# 2     1
# 3     1
# 4     3
# 5     0
# 6     1
# 7     1
# 8     2
# 9     4
# 10    1
# 11    0
# 12    0
# dtype: int64

# %%
df[df.isna().any(axis=1)]
# Out:
#        0             1      2      3            4   \
# 4     NaN   Doug Walker    NaN    NaN          NaN
# 55  Color    Peter Sohn  298.0   93.0  123070338.0
# 84  Color  Roland Joffé   10.0  109.0          NaN
# 98  Color  Hideaki Anno    1.0  120.0          NaN
#
#                                                    5      6        7    8   \
# 4   Star Wars: Episode VII - The Force Awakens    ...    NaN      NaN  NaN
# 55                                 The Good Dinosaur   345.0      USA   PG
# 84                                        The Lovers    15.0  Belgium    R
# 98                               Godzilla Resurgence    13.0    Japan  NaN
#
#      9       10   11           12
# 4   NaN     NaN  7.1  Documentary
# 55  NaN  2015.0  6.8    Adventure
# 84  NaN  2015.0  4.5       Action
# 98  NaN  2016.0  8.2       Action

# %%
df = df.dropna()

# %%
df
# Out:
#        0                  1      2      3            4   \
# 0   Color      James Cameron  723.0  178.0  760505847.0
# 1   Color     Gore Verbinski  302.0  169.0  309404152.0
# 2   Color         Sam Mendes  602.0  148.0  200074175.0
# 3   Color  Christopher Nolan  813.0  164.0  448130642.0
# 5   Color     Andrew Stanton  462.0  132.0   73058679.0
# ..    ...                ...    ...    ...          ...
# 94  Color    Jonathan Mostow  280.0  109.0  150350192.0
# 95  Color         James Gunn  653.0  121.0  333130696.0
# 96  Color  Christopher Nolan  712.0  169.0  187991439.0
# 97  Color  Christopher Nolan  642.0  148.0  292568851.0
# 99  Color      Peter Jackson  645.0  182.0  303001229.0
#
#                                            5       6    7      8   \
# 0                                     Avatar   3054.0  USA  PG-13
# 1   Pirates of the Caribbean: At World's End   1238.0  USA  PG-13
# 2                                    Spectre    994.0   UK  PG-13
# 3                      The Dark Knight Rises   2701.0  USA  PG-13
# 5                                John Carter    738.0  USA  PG-13
# ..                                        ...     ...  ...    ...
# 94        Terminator 3: Rise of the Machines   1676.0  USA      R
# 95                   Guardians of the Galaxy   1097.0  USA  PG-13
# 96                              Interstellar   2725.0  USA  PG-13
# 97                                 Inception   2803.0  USA  PG-13
# 99         The Hobbit: An Unexpected Journey   1367.0  USA  PG-13
#
#                9       10   11         12
# 0   237,000,000.0  2009.0  7.9     Action
# 1   300,000,000.0  2007.0  7.1     Action
# 2   245,000,000.0  2015.0  6.8     Action
# 3   250,000,000.0  2012.0  8.5     Action
# 5   263,700,000.0  2012.0  6.6     Action
# ..            ...     ...  ...        ...
# 94  200,000,000.0  2003.0  6.4     Action
# 95  170,000,000.0  2014.0  8.1     Action
# 96  165,000,000.0  2014.0  8.6  Adventure
# 97  160,000,000.0  2010.0  8.8     Action
# 99  180,000,000.0  2012.0  7.9  Adventure
#
# [96 rows x 13 columns]

# %%
column_names = ['color', 'director_name', 'num_critic_for_reviews', 'duration',
                'gross', 'movie_title', 'num_user_for_reviews',	'country',
                'cotent_rating', 'budget', 'title_year', 'imdb_score', 'genre']

# %%
df.columns = column_names
df
# Out:
#     color      director_name  num_critic_for_reviews  duration        gross  \
# 0   Color      James Cameron                   723.0     178.0  760505847.0
# 1   Color     Gore Verbinski                   302.0     169.0  309404152.0
# 2   Color         Sam Mendes                   602.0     148.0  200074175.0
# 3   Color  Christopher Nolan                   813.0     164.0  448130642.0
# 5   Color     Andrew Stanton                   462.0     132.0   73058679.0
# ..    ...                ...                     ...       ...          ...
# 94  Color    Jonathan Mostow                   280.0     109.0  150350192.0
# 95  Color         James Gunn                   653.0     121.0  333130696.0
# 96  Color  Christopher Nolan                   712.0     169.0  187991439.0
# 97  Color  Christopher Nolan                   642.0     148.0  292568851.0
# 99  Color      Peter Jackson                   645.0     182.0  303001229.0
#
#                                   movie_title  num_user_for_reviews country  \
# 0                                     Avatar                 3054.0     USA
# 1   Pirates of the Caribbean: At World's End                 1238.0     USA
# 2                                    Spectre                  994.0      UK
# 3                      The Dark Knight Rises                 2701.0     USA
# 5                                John Carter                  738.0     USA
# ..                                        ...                   ...     ...
# 94        Terminator 3: Rise of the Machines                 1676.0     USA
# 95                   Guardians of the Galaxy                 1097.0     USA
# 96                              Interstellar                 2725.0     USA
# 97                                 Inception                 2803.0     USA
# 99         The Hobbit: An Unexpected Journey                 1367.0     USA
#
#    cotent_rating         budget  title_year  imdb_score      genre
# 0          PG-13  237,000,000.0      2009.0         7.9     Action
# 1          PG-13  300,000,000.0      2007.0         7.1     Action
# 2          PG-13  245,000,000.0      2015.0         6.8     Action
# 3          PG-13  250,000,000.0      2012.0         8.5     Action
# 5          PG-13  263,700,000.0      2012.0         6.6     Action
# ..           ...            ...         ...         ...        ...
# 94             R  200,000,000.0      2003.0         6.4     Action
# 95         PG-13  170,000,000.0      2014.0         8.1     Action
# 96         PG-13  165,000,000.0      2014.0         8.6  Adventure
# 97         PG-13  160,000,000.0      2010.0         8.8     Action
# 99         PG-13  180,000,000.0      2012.0         7.9  Adventure
#
# [96 rows x 13 columns]

# %%
df.loc[(df['imdb_score'] > 8)]
# Out:
#     color      director_name  num_critic_for_reviews  duration        gross  \
# 3   Color  Christopher Nolan                   813.0     164.0  448130642.0
# 17  Color        Joss Whedon                   703.0     173.0  623279547.0
# 27  Color      Anthony Russo                   516.0     147.0  407197282.0
# 43  Color        Lee Unkrich                   453.0     103.0  414984497.0
# 58  Color     Andrew Stanton                   421.0      98.0  223806889.0
# 66  Color  Christopher Nolan                   645.0     152.0  533316061.0
# 67  Color        Pete Docter                   408.0      96.0  292979556.0
# 78  Color        Pete Docter                   536.0      95.0  356454367.0
# 93  Color       Dean DeBlois                   288.0      98.0  217387997.0
# 95  Color         James Gunn                   653.0     121.0  333130696.0
# 96  Color  Christopher Nolan                   712.0     169.0  187991439.0
# 97  Color  Christopher Nolan                   642.0     148.0  292568851.0
#
#                     movie_title  num_user_for_reviews country cotent_rating  \
# 3        The Dark Knight Rises                 2701.0     USA         PG-13
# 17                The Avengers                 1722.0     USA         PG-13
# 27  Captain America: Civil War                 1022.0     USA         PG-13
# 43                 Toy Story 3                  733.0     USA             G
# 58                      WALL·E                 1043.0     USA             G
# 66             The Dark Knight                 4667.0     USA         PG-13
# 67                          Up                  704.0     USA            PG
# 78                  Inside Out                  773.0     USA            PG
# 93    How to Train Your Dragon                  492.0     USA            PG
# 95     Guardians of the Galaxy                 1097.0     USA         PG-13
# 96                Interstellar                 2725.0     USA         PG-13
# 97                   Inception                 2803.0     USA         PG-13
#
#            budget  title_year  imdb_score      genre
# 3   250,000,000.0      2012.0         8.5     Action
# 17  220,000,000.0      2012.0         8.1     Action
# 27  250,000,000.0      2016.0         8.2     Action
# 43  200,000,000.0      2010.0         8.3  Adventure
# 58  180,000,000.0      2008.0         8.4  Adventure
# 66  185,000,000.0      2008.0         9.0     Action
# 67  175,000,000.0      2009.0         8.3  Adventure
# 78  175,000,000.0      2015.0         8.3  Adventure
# 93  165,000,000.0      2010.0         8.2  Adventure
# 95  170,000,000.0      2014.0         8.1     Action
# 96  165,000,000.0      2014.0         8.6  Adventure
# 97  160,000,000.0      2010.0         8.8     Action

# %%
df.duplicated().any().sum()
# Out:
# 0

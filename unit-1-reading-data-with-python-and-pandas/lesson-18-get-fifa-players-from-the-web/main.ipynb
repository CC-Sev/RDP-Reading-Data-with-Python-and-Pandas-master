# %%
import numpy as np
import pandas as pd
import requests

# %%
df = pd.read_html('files/fifa_players.html', header = 0)[0]

# %%
df
# Out:
#     Unnamed: 0  Unnamed: 1  OVR-POT                        Name  \
# 0          NaN         NaN     7587       Erling Braut  HÃ¥land
# 1          NaN         NaN     9393           Cristiano Ronaldo
# 2          NaN         NaN     9494                Lionel Messi
# 3          NaN         NaN     8995              Kylian MbappÃ©
# 4          NaN         NaN     8492                Jadon Sancho
# 5          NaN         NaN     9292                   Neymar Jr
# 6          NaN         NaN     8692             Frenkie de Jong
# 7          NaN         NaN     8892                Paulo Dybala
# 8          NaN         NaN     8187           Donny van de Beek
# 9          NaN         NaN     7685               Tammy Abraham
# 10         NaN         NaN     9191                 Eden Hazard
# 11         NaN         NaN     9090               Mohamed Salah
# 12         NaN         NaN     8788               Heung Min Son
# 13         NaN         NaN     8585        Zlatan  IbrahimoviÄ
# ...

# %%
def test_fifa_1():
    assert fifa_df.shape == (30, 5)

# %%
df.shape
# Out:
# (30, 8)

# %%
df = df.drop(columns=['Unnamed: 0'])

# %%
df = df.drop(columns=['Unnamed: 1', 'Unnamed: 7'])

# %%
df.shape
# Out:
# (30, 5)

# %%
def test_fifa_2():
    assert fifa_df.loc[:,'Age'].sum() == 746

# %%
df['Age'].sum()
# Out:
# 746

# %%
df['Age'].sum() == 746
# Out:
# True

# %%
def test_most_hits():
    assert most_hits_player['Name'][0] == 'Erling Braut  Håland'

# %%
top_hitter = df['Name'][0]

# %%
top_hitter == 'Erling Braut  HÃ¥land'
# Out:
# True

# %%
top_hitter
# Out:
# 'Erling Braut  HÃ¥land'
